# %%
filepath = 'C:\\districting-data-2010\\'

# 1. Code takes Daryl's block-level .json files and 
#    adds the lat/lon coordinates to the nodes
#    (based on the census shapefiles)
#
#outfilepath1 = 'C:\\districting-data-2020-lat-lon\\'

# 2. Then connects any disconnected graphs by adding
#    a minimum length subset of edges.
#
outfilepath2 = 'C:\\districting-data-2010-conn\\'

# %%
import os
if not os.path.exists(outfilepath2):
    os.makedirs(outfilepath2)

# %%
import geopandas as gpd
from gerrychain import Graph
import networkx as nx

# %%
state_codes = {
    'WA': '53', 'DE': '10', 'WI': '55', 'WV': '54', 'HI': '15',
    'FL': '12', 'WY': '56', 'NJ': '34', 'NM': '35', 'TX': '48',
    'LA': '22', 'NC': '37', 'ND': '38', 'NE': '31', 'TN': '47', 'NY': '36',
    'PA': '42', 'AK': '02', 'NV': '32', 'NH': '33', 'VA': '51', 'CO': '08',
    'CA': '06', 'AL': '01', 'AR': '05', 'VT': '50', 'IL': '17', 'GA': '13',
    'IN': '18', 'IA': '19', 'MA': '25', 'AZ': '04', 'ID': '16', 'CT': '09',
    'ME': '23', 'MD': '24', 'OK': '40', 'OH': '39', 'UT': '49', 'MO': '29',
    'MN': '27', 'MI': '26', 'RI': '44', 'KS': '20', 'MT': '30', 'MS': '28',
    'SC': '45', 'KY': '21', 'OR': '41', 'SD': '46'
}

# %%
import json
from networkx.readwrite import json_graph

def write_graph_to_json(graph, json_file):
    data = json_graph.adjacency_data(graph)
    with open(json_file, "w") as f:
        json.dump(data,f)
    return

# %%
from math import cos, asin, sqrt, pi

# get approximate distance between lat/long coordinates:
# https://stackoverflow.com/questions/27928/calculate-distance-between-two-latitude-longitude-points-haversine-formula?noredirect=1&lq=1
def apx_dist(lat1, lon1, lat2, lon2):
    p = pi/180
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 12.742 * asin(sqrt(a)) #2*R*asin...

# %%
for state in state_codes.keys():
    
    print("Beginning state",state)
    
    # read graph from file
    graphfile = state + '_block.json'
    G = Graph.from_json( filepath + graphfile )

#     # read the shapefile
#     shpfile = state + '_block.shp'
#     df = gpd.read_file( filepath + shpfile )
    
#     # add the lat/lon coordinates to graph (based on shapefile)
#     geoid_to_node = { G.nodes[i]['GEOID20'] : i for i in G.nodes }
#     for u in range(len(G.nodes)):
#         geoid = df['GEOID20'][u]
#         i = geoid_to_node[geoid]
#         G.nodes[i]['INTPTLAT20'] = float( df['INTPTLAT20'][u] )
#         G.nodes[i]['INTPTLON20'] = float( df['INTPTLON20'][u] )
        
#     # write the lat/lon-adjusted graph to output1
#     write_graph_to_json(G, outfilepath1 + graphfile)
    
    # is graph connected?
    if nx.is_connected(G):
        
        print("Graph is already connected.")
        
    else:
        
        # if not, then connect it with least-cost edges
        components = list(nx.connected_components(G))
        H = nx.complete_graph(len(components))

        for c in range(len(components)):
            component = components[c]
            print("Component",c,"has this many nodes:",len(component))

        for i,j in H.edges:

            min_dist = 999999999999.0 # some large number
            min_dist_edge = None

            for u in components[i]:

                lat1 = G.nodes[u]['C_Y']
                lon1 = G.nodes[u]['C_X']

                for v in components[j]:

                    lat2 = G.nodes[v]['C_Y']
                    lon2 = G.nodes[v]['C_X']

                    dist = apx_dist(lat1, lon1, lat2, lon2)

                    if dist < min_dist:

                        min_dist = dist
                        min_dist_edge = (u,v)

            H.edges[i,j]['weight'] = min_dist
            H.edges[i,j]['G_edge'] = min_dist_edge

        # find min span tree of H
        T = nx.minimum_spanning_tree(H,weight='weight')
        print("Spanning tree edges in H are =",T.edges)

        # which edges does this correspond to in G?
        edges_to_add = [ T.edges[i,j]['G_edge'] for i,j in T.edges ]
        print("Adding these edges to G =",edges_to_add)
        G.add_edges_from(edges_to_add)

        # print their GEOIDs for later reference
        added_edges_geoids = [ ( G.nodes[i]['geoid'], G.nodes[j]['geoid'] ) for i,j in edges_to_add ]
        print("Their GEOIDs are =",added_edges_geoids)

        # make sure G is now connected
        print("After adding these edges, is G now connected?",nx.is_connected(G))
        
    print("")
    # write the lat/lon-adjusted *and connected* graph to output2
    write_graph_to_json(G, outfilepath2 + graphfile)
# Out:
# Beginning state WA
# Graph is already connected.
#
# Beginning state DE
# Graph is already connected.
#
# Beginning state WI
# Graph is already connected.
#
# Beginning state WV
# Graph is already connected.
#
# Beginning state HI
# Component 0 has this many nodes: 8888
# Component 1 has this many nodes: 8819
# Component 2 has this many nodes: 3
# Component 3 has this many nodes: 18
# Component 4 has this many nodes: 3
# Component 5 has this many nodes: 16
# Component 6 has this many nodes: 4
# Component 7 has this many nodes: 4
# Component 8 has this many nodes: 5
# Component 9 has this many nodes: 3
# Component 10 has this many nodes: 852
# Component 11 has this many nodes: 2939
# Component 12 has this many nodes: 31
# Component 13 has this many nodes: 5
# Component 14 has this many nodes: 3088
# Component 15 has this many nodes: 338
# Spanning tree edges in H are = [(0, 14), (1, 10), (1, 11), (2, 9), (2, 5), (3, 6), (3, 4), (4, 9), (5, 8), (6, 7), (7, 13), (10, 15), (11, 12), (12, 13), (14, 15)]
# Adding these edges to G = [(3001, 23214), (11654, 23037), (15749, 20614), (10761, 14156), (9638, 16346), (15273, 9648), (9641, 9642), (16344, 17455), (9645, 16348), (17454, 9650), (11900, 19947), (23747, 21117), (18980, 18144), (20369, 18119), (23601, 24686)]
# Their GEOIDs are = [('150010218002014', '150099902000021'), ('150039900010052', '150099900000003'), ('150039900010033', '150079901000006'), ('150039812001047', '150039812001039'), ('150039812001046', '150039812001033'), ('150039812001012', '150039812001040'), ('150039812001008', '150039812001045'), ('150039812001027', '150039812001037'), ('150039812001024', '150039812001032'), ('150039812001042', '150039812001001'), ('150039812001000', '150079903000002'), ('150099900000011', '150099912000004'), ('150070409001043', '150070412001010'), ('150070412001014', '150079903000001'), ('150099902000039', '150099912000005')]
# After adding these edges, is G now connected? True
#
# Beginning state FL
# Component 0 has this many nodes: 484466
# Component 1 has this many nodes: 15
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(297455, 298016)]
# Their GEOIDs are = [('120879725001031', '120879801001013')]
# After adding these edges, is G now connected? True
#
# Beginning state WY
# Graph is already connected.
#
# Beginning state NJ
# Graph is already connected.
#
# Beginning state NM
# Graph is already connected.
#
# Beginning state TX
# Graph is already connected.
#
# Beginning state LA
# Graph is already connected.
#
# Beginning state NC
# Graph is already connected.
#
# Beginning state ND
# Graph is already connected.
#
# Beginning state NE
# Graph is already connected.
#
# Beginning state TN
# Graph is already connected.
#
# Beginning state NY
# C:\Users\buchanan\Anaconda3\lib\site-packages\gerrychain\graph\graph.py:239: UserWarning: Found islands (degree-0 nodes). Indices of islands: {162526, 163399}
#   "Found islands (degree-0 nodes). Indices of islands: {}".format(islands)
# Component 0 has this many nodes: 350167
# Component 1 has this many nodes: 1
# Component 2 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1), (1, 2)]
# Adding these edges to G = [(163199, 162526), (162526, 163399)]
# Their GEOIDs are = [('360610005000002', '360610001001000'), ('360610001001000', '360610001001001')]
# After adding these edges, is G now connected? True
#
# Beginning state PA
# Graph is already connected.
#
# Beginning state AK
# C:\Users\buchanan\Anaconda3\lib\site-packages\gerrychain\graph\graph.py:239: UserWarning: Found islands (degree-0 nodes). Indices of islands: {1316, 1637, 1924, 1799, 584, 1321, 426, 1630, 2219, 9357, 22986, 29990, 29169, 29306, 1182, 8255}
#   "Found islands (degree-0 nodes). Indices of islands: {}".format(islands)
# Component 0 has this many nodes: 42381
# Component 1 has this many nodes: 524
# Component 2 has this many nodes: 45
# Component 3 has this many nodes: 11
# Component 4 has this many nodes: 1
# Component 5 has this many nodes: 1
# Component 6 has this many nodes: 2
# Component 7 has this many nodes: 8
# Component 8 has this many nodes: 60
# Component 9 has this many nodes: 12
# Component 10 has this many nodes: 446
# Component 11 has this many nodes: 30
# Component 12 has this many nodes: 5
# Component 13 has this many nodes: 6
# Component 14 has this many nodes: 29
# Component 15 has this many nodes: 15
# Component 16 has this many nodes: 70
# Component 17 has this many nodes: 14
# Component 18 has this many nodes: 2
# Component 19 has this many nodes: 1
# Component 20 has this many nodes: 34
# Component 21 has this many nodes: 21
# Component 22 has this many nodes: 1
# Component 23 has this many nodes: 1
# Component 24 has this many nodes: 10
# Component 25 has this many nodes: 4
# Component 26 has this many nodes: 6
# Component 27 has this many nodes: 3
# Component 28 has this many nodes: 1
# Component 29 has this many nodes: 4
# Component 30 has this many nodes: 1
# Component 31 has this many nodes: 1
# Component 32 has this many nodes: 1
# Component 33 has this many nodes: 1
# Component 34 has this many nodes: 96
# Component 35 has this many nodes: 8
# Component 36 has this many nodes: 1
# Component 37 has this many nodes: 4
# Component 38 has this many nodes: 1
# Component 39 has this many nodes: 1335
# Component 40 has this many nodes: 11
# Component 41 has this many nodes: 16
# Component 42 has this many nodes: 1
# Component 43 has this many nodes: 51
# Component 44 has this many nodes: 3
# Component 45 has this many nodes: 1
# Component 46 has this many nodes: 4
# Component 47 has this many nodes: 1
# Component 48 has this many nodes: 1
# Component 49 has this many nodes: 6
# Spanning tree edges in H are = [(0, 6), (0, 41), (0, 47), (0, 4), (0, 37), (0, 1), (0, 48), (0, 3), (0, 5), (0, 2), (0, 34), (0, 45), (0, 40), (0, 44), (0, 49), (0, 43), (1, 21), (1, 22), (7, 17), (8, 33), (8, 11), (9, 15), (9, 16), (9, 23), (10, 25), (10, 19), (10, 31), (10, 18), (10, 27), (11, 22), (12, 13), (12, 21), (13, 27), (14, 32), (14, 28), (17, 18), (17, 30), (17, 29), (20, 26), (20, 29), (23, 32), (24, 26), (24, 28), (34, 35), (35, 36), (37, 38), (39, 41), (40, 42), (45, 46)]
# Adding these edges to G = [(851, 992), (20072, 22900), (29855, 29306), (499, 426), (9952, 10040), (75, 242), (29303, 29990), (699, 1090), (802, 584), (1029, 534), (7830, 7064), (29581, 29169), (23805, 22033), (30302, 29827), (38561, 39128), (29690, 29351), (1763, 2277), (1938, 1316), (1376, 1638), (1729, 2219), (1418, 2157), (1870, 1835), (1870, 2271), (1871, 1321), (2047, 1933), (2210, 1182), (1508, 1799), (1982, 1174), (1875, 1802), (1149, 1316), (1137, 1419), (1840, 1917), (2276, 1802), (1925, 1924), (1171, 1630), (1493, 1175), (1494, 1637), (1638, 2273), (1218, 1689), (1337, 1929), (1321, 1924), (1688, 2161), (2071, 1630), (7906, 7966), (7966, 8255), (9948, 9357), (22150, 23489), (22409, 22986), (29169, 29170)]
# Their GEOIDs are = [('020130001002351', '020130001002391'), ('021220012001219', '021500001002006'), ('021800001005003', '021800001005102'), ('020130001001053', '020130001001452'), ('020700001003104', '020700001003151'), ('020130001001175', '020130001001324'), ('021800001004065', '021800001004168'), ('020130001003213', '020130001003240'), ('020130001001028', '020130001001451'), ('020130001001214', '020130001001408'), ('020500001001058', '020500001001091'), ('021800001001084', '021800001001125'), ('021640001002350', '021500001001495'), ('021800001002098', '021800001002298'), ('022610003001514', '022610002001427'), ('021800002002029', '021800001006001'), ('020160001001603', '020160001001436'), ('020160001001613', '020160001001682'), ('020160001001802', '020160001001394'), ('020160001001459', '020160001001000'), ('020160001001456', '020160001001647'), ('020160001001732', '020160001001723'), ('020160001001732', '020160001001550'), ('020160001001739', '020160001001841'), ('020160001001015', '020160001001824'), ('020160001001054', '020160001001833'), ('020160001001127', '020160001001844'), ('020160001001377', '020160001001829'), ('020160001001147', '020160001001679'), ('020160001001642', '020160001001682'), ('020160001001632', '020160001001813'), ('020160001001634', '020160001001446'), ('020160001001816', '020160001001679'), ('020160001001696', '020160001001846'), ('020160001001708', '020160001001835'), ('020160001001402', '020160001001830'), ('020160001001399', '020160001001831'), ('020160001001394', '020160001001808'), ('020160001001518', '020160001001786'), ('020160001001508', '020160001001805'), ('020160001001841', '020160001001846'), ('020160001001423', '020160001001783'), ('020160001001420', '020160001001835'), ('020500001001139', '020500001001184'), ('020500001001184', '020500001001179'), ('020700001003152', '020700001003106'), ('021500001002052', '021500001002010'), ('021500001001499', '021500001001543'), ('021800001001125', '021800001001138')]
# After adding these edges, is G now connected? True
#
# Beginning state NV
# Graph is already connected.
#
# Beginning state NH
# Graph is already connected.
#
# Beginning state VA
# Graph is already connected.
#
# Beginning state CO
# Graph is already connected.
#
# Beginning state CA
# Component 0 has this many nodes: 709827
# Component 1 has this many nodes: 72
# Component 2 has this many nodes: 155
# Component 3 has this many nodes: 4
# Component 4 has this many nodes: 70
# Component 5 has this many nodes: 6
# Component 6 has this many nodes: 11
# Spanning tree edges in H are = [(0, 4), (0, 3), (0, 2), (1, 2), (2, 5), (5, 6)]
# Adding these edges to G = [(697748, 689902), (283400, 529654), (261153, 218876), (165057, 178917), (247325, 571866), (578383, 697745)]
# Their GEOIDs are = [('061119901000032', '061110036121001'), ('060411322003015', '060759804011001'), ('060379903000035', '060375991002003'), ('060375991001011', '060375991002079'), ('060375991002000', '060839801001036'), ('060839801001035', '061119800001002')]
# After adding these edges, is G now connected? True
#
# Beginning state AL
# Graph is already connected.
#
# Beginning state AR
# Graph is already connected.
#
# Beginning state VT
# Graph is already connected.
#
# Beginning state IL
# Graph is already connected.
#
# Beginning state GA
# Graph is already connected.
#
# Beginning state IN
# Graph is already connected.
#
# Beginning state IA
# Graph is already connected.
#
# Beginning state MA
# Graph is already connected.
#
# Beginning state AZ
# Graph is already connected.
#
# Beginning state ID
# Graph is already connected.
#
# Beginning state CT
# Graph is already connected.
#
# Beginning state ME
# Graph is already connected.
#
# Beginning state MD
# Graph is already connected.
#
# Beginning state OK
# Graph is already connected.
#
# Beginning state OH
# Graph is already connected.
#
# Beginning state UT
# Graph is already connected.
#
# Beginning state MO
# Graph is already connected.
#
# Beginning state MN
# Graph is already connected.
#
# Beginning state MI
# Graph is already connected.
#
# Beginning state RI
# Component 0 has this many nodes: 25081
# Component 1 has this many nodes: 100
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(23226, 24635)]
# Their GEOIDs are = [('440099901000027', '440099902000001')]
# After adding these edges, is G now connected? True
#
# Beginning state KS
# Graph is already connected.
#
# Beginning state MT
# Graph is already connected.
#
# Beginning state MS
# Graph is already connected.
#
# Beginning state SC
# Graph is already connected.
#
# Beginning state KY
# Component 0 has this many nodes: 161665
# Component 1 has this many nodes: 7
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(47134, 47049)]
# Their GEOIDs are = [('210759602004002', '210759602004157')]
# After adding these edges, is G now connected? True
#
# Beginning state OR
# Graph is already connected.
#
# Beginning state SD
# Graph is already connected.
